# %%
import pandas as pd

# %%
bio_df = pd.read_csv("Olympic_Athlete_Event_Results.csv")
bio_df
# Out:
#                      edition  edition_id country_noc      sport  \
# 0       1908 Summer Olympics           5         ANZ  Athletics
# 1       1908 Summer Olympics           5         ANZ  Athletics
# 2       1908 Summer Olympics           5         ANZ  Athletics
# 3       1908 Summer Olympics           5         ANZ  Athletics
# 4       1908 Summer Olympics           5         ANZ  Athletics
# ...                      ...         ...         ...        ...
# 316829  2022 Winter Olympics          62         NED  Bobsleigh
# 316830  2022 Winter Olympics          62         SVK  Bobsleigh
# 316831  2022 Winter Olympics          62         KOR  Bobsleigh
# 316832  2022 Winter Olympics          62         JAM  Bobsleigh
# 316833  2022 Winter Olympics          62         UKR  Bobsleigh
#
#                   event  result_id                     athlete  athlete_id  \
# 0       100 metres, Men      56265             Ernest Hutcheon       64710
# ...

# %%
bio_df = bio_df.dropna(how="any")

# %%
bio_df
# Out:
#                      edition  edition_id country_noc          sport  \
# 20      1908 Summer Olympics           5         ANZ      Athletics
# 30      1908 Summer Olympics           5         ANZ         Boxing
# 32      1908 Summer Olympics           5         ANZ          Rugby
# 33      1908 Summer Olympics           5         ANZ          Rugby
# 34      1908 Summer Olympics           5         ANZ          Rugby
# ...                      ...         ...         ...            ...
# 316804  2022 Winter Olympics          62         USA  Speed Skating
# 316807  2022 Winter Olympics          62         USA  Speed Skating
# 316814  2022 Winter Olympics          62         USA      Bobsleigh
# 316815  2022 Winter Olympics          62         USA      Bobsleigh
# 316816  2022 Winter Olympics          62         CAN      Bobsleigh
#
#                               event  result_id              athlete  \
# 20      3,500 metres Race Walk, Men      56421           Harry Kerr
# ...

# %%
bio_df.to_csv("Olympic_Athlete_Event_Results.csv")
